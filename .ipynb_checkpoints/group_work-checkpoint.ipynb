# %%
# !curl  -o FremontBridge.csv https://data.seattle.gov/api/views/65db-xm6k/rows.csv?accessType=DOWNLOAD

# %%
import numpy as np
import pandas as pd
import seaborn; seaborn.set()

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('FremontBridge.csv')
data.head()
# Out:
#                      Date  Fremont Bridge East Sidewalk  \
# 0  04/30/2019 11:00:00 PM                           8.0
# 1  04/30/2019 10:00:00 PM                          15.0
# 2  04/30/2019 09:00:00 PM                          17.0
# 3  04/30/2019 08:00:00 PM                          58.0
# 4  04/30/2019 07:00:00 PM                         106.0
#
#    Fremont Bridge West Sidewalk
# 0                          16.0
# 1                          29.0
# 2                          54.0
# 3                          91.0
# 4                         175.0

# %%
data.columns
# Out:
# Index(['Date', 'Fremont Bridge East Sidewalk', 'Fremont Bridge West Sidewalk'], dtype='object')

# %%
# カラム名を省略する
renamed_data = data.rename(columns = {'Fremont Bridge East Sidewalk':'East','Fremont Bridge West Sidewalk':'West'})
renamed_data.head()
# Out:
#                      Date   East   West
# 0  04/30/2019 11:00:00 PM    8.0   16.0
# 1  04/30/2019 10:00:00 PM   15.0   29.0
# 2  04/30/2019 09:00:00 PM   17.0   54.0
# 3  04/30/2019 08:00:00 PM   58.0   91.0
# 4  04/30/2019 07:00:00 PM  106.0  175.0

# %%
renamed_data.columns
# Out:
# Index(['Date', 'East', 'West'], dtype='object')

# %% [markdown]
# ## eval()　とは

# %%
renamed_data['Total'] = renamed_data.eval('West + East')

# %% [markdown]
# ## dropna(), describe() とは

# %%
renamed_data.dropna().describe()
# Out:
#                East          West         Total
# count  57615.000000  57615.000000  57615.000000
# mean      51.916914     58.359889    110.276803
# std       67.368033     84.958511    139.743003
# min        0.000000      0.000000      0.000000
# 25%        6.000000      7.000000     14.000000
# 50%       28.000000     29.000000     60.000000
# 75%       69.000000     70.000000    143.000000
# max      698.000000    717.000000    957.000000

# %%
renamed_data.plot()
plt.ylabel('hourly Bicycle Count');

# %% [markdown]
# ## resample()とは
# ## resampleを使うためにrangeindex→datatimeindex

# %%
weekly = renamed_data.resample('W').sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-e72ff3bae700> in <module>()
# ----> 1 weekly = renamed_data.resample('W').sum()
#
# ~/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/pandas/core/generic.py in resample(self, rule, how, axis, fill_method, closed, label, convention, kind, loffset, limit, base, on, level)
#    4727                      axis=axis, kind=kind, loffset=loffset,
#    4728                      convention=convention,
# -> 4729                      base=base, key=on, level=level)
#    4730         return _maybe_process_deprecations(r,
#    4731                                            how=how,
#
# ~/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/pandas/core/resample.py in resample(obj, kind, **kwds)
#     967     """ create a TimeGrouper and return our resampler """
#     968     tg = TimeGrouper(**kwds)
# ...

# %%
# indexの型を変える
renamed_data.index = pd.to_datetime(renamed_data['Date'])
weekly = renamed_data.resample('W').sum()

# %%
weekly.plot(style=[':', '--','-'])
plt.ylabel('Weekly Bicycle Count')
# Out:
# Text(0,0.5,'Weekly Bicycle Count')

# %%
daily = renamed_data.resample('D').sum()
daily.rolling(30,center = True).sum().plot(style = [':','--','-'])
plt.ylabel('mean hourly count')
# Out:
# Text(0,0.5,'mean hourly count')

# %% [markdown]
# ## rolling() とは

# %%
daily.rolling(50,center = True,win_type='gaussian').sum(std=10).plot(style = [':','--','-']);

# %% [markdown]
# ## groupby()

# %%
by_time = renamed_data.groupby(renamed_data.index.time).mean()
hourly_ticks = 4*60*60*np.arange(6)
by_time.plot(xticks = hourly_ticks, style = [':','--','-']);

# %%
by_weekday = renamed_data.groupby(renamed_data.index.dayofweek).mean()
by_weekday.index = ['Mon','Tues','Wed','Thurs','Fri','Sat','Sun']
by_weekday.plot(style = [':','--','-']);

# %% [markdown]
# ## where()　とは

# %%
weekend = np.where(renamed_data.index.weekday < 5, 'Weekday', 'Weekend')
by_time = renamed_data.groupby([weekend, renamed_data.index.time]).mean()

# %% [markdown]
# ## subplotについて
# ## ix,loc,ilocの違い

# %%
fig, ax = plt.subplots(1, 2, figsize=(14, 5))
by_time.ix['Weekday'].plot(ax=ax[0], title='Weekdays', xticks = hourly_ticks, style = [':','--','-'])
by_time.ix['Weekend'].plot(ax=ax[1], title='Weekends', xticks = hourly_ticks, style = [':','--','-'])
# Out:
# /Users/yosuke/.pyenv/versions/anaconda3-5.0.1/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %%
fig, ax = plt.subplots(1, 2, figsize=(14, 5))
by_time.loc['Weekday'].plot(ax=ax[0], title='Weekdays', xticks = hourly_ticks, style = [':','--','-'])
by_time.loc['Weekend'].plot(ax=ax[1], title='Weekends', xticks = hourly_ticks, style = [':','--','-'])
